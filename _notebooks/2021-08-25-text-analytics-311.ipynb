# %% [markdown]
# # Text Analytics with 3-1-1 Call Data
# > An attempt at text analytics using non-emergency service calls.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [jupyter]
# - image: images/cincy_skyline.jpg

# %% [markdown]
# ## Flow
# - overview of TF-IDF
# - remove stop words
# - look at index of % services by department cut by neighborhood/time to showcase how we learn more from text analytics
# - look at top words overall (these might be automated responses, if so remove)
# - run tf-idf by zip code for set time period
#      - explore differences between Hyde Park and Avondale
# - run tf-idf by month for all neighbordhoods over set time period
#      - explore differences between a single month per season

# %% [markdown]
# # About
#
# Text analytics represents a growing set of tools to uncover insights on texts of interest.  In industry, this may include mining customer reviews or .
#
# The set of tools is strong and enables us to 'listen' to people in a programmatic way.  Text analytics obviously has limitations compared to the understanding that comes from an actual human reading the text, but for processing large amounts of data it can be an effective tool within the confines of its limitations.

# %% [markdown]
# ## In this Post
#
# This notebook will demonstrate various text mining techniques, with our subject being 3-1-1 call data.  3-1-1 Call Centers are common in municipalities and represent a non-emergency hotline for residents to contact.  Incidents reported include fallen limbs, potholes, overgrown footprints, and much more.
#
# Text mining was a new topic for me.  I have been exposed to trainings in the past but have never wandered into the wild lands of raw text descriptions and tried to make better sense of them programmatically.  This ended up being a fun exercise with a ton of text cleaning and I learned a lot - I hope you do as well!

# %% [markdown]
# ## Why is this Important
#
# Querying and accessing data is a fundamental step of any data science workflow.  The mechanics of accessing data can get very messy, especially when it comes to government data.  Examples of this messiness include manually downloading files and saving to a user-defined location, appending multiple Excel files, scraping PDFs, and the list goes on.  Bottom line: it can get MESSY.
#
# Luckily, the infrastructure provided by Socrata makes for a seamless experience that can be replicated by anyone with the Internet and Python.  You read that correctly, everything demonstrated in this post can be replicated with very little setup.  This is a huge perk for the sake of collaboration.  Additionally, in the event that an analysis needs to be re-run, perhaps on more recent data, the ability to query data programatically allows for minimal rework and minimal room for error.  Alright, enough hype let's get to it!

# %% [markdown]
# ## Setup
#
# Before we get rolling, it is important to be working in an environment with the necessary packages installed and available.  For this post we will need the `pandas`, `datetime` and `nltk` libraries installed.  As mentioned before, I like using conda to manage dependencies and would encourage others to go that route.

# %%
import pandas as pd
import datetime as dt
import numpy as np
import plotly.express as px

pd.options.display.max_colwidth = 100

# function takes five arguments (endpoint_url and 4 components of the query) 
# function returns a full, cleaned up API call
def generate_query(endpoint_url, query, limit):

    raw_query = (f"{endpoint_url}?$query="
                 f"{query}%20"
                 f"limit {limit}"
                )
    
    # get rid of control characters
    for replacements in ((" ", "%20"), ("\n", "%20")):
        raw_query = raw_query.replace(*replacements)
    
    return raw_query

# %% [markdown]
# ## Initial Read
#
# We are going to read in the past year of 3-1-1 call data for this exploration.

# %%
# define our base API endpoint
endpoint_311 = 'https://data.cincinnati-oh.gov/resource/4cjh-bm8b.json'

# dynamically generate today's date
today = dt.date.today()

# dynamically arrive at the date exactly 365 days ago
year_ago_today = today - dt.timedelta(days = 365)

# %% [markdown]
# Use our function to build a query.

# %%
pd.read_json(endpoint_311).head(5)
# Out:
#   jurisdiction_id service_request_id status                      service_name  \
# 0      CINCINNATI         SR14009513   CLOS  "Metal Furniture, Spec Collectn"
# 1      CINCINNATI         SR14009514   CLOS         "Sign, street sign faded"
# 2      CINCINNATI         SR14009515   CLOS       "Slippery streets, request"
# 3      CINCINNATI         SR14009516   CLOS   "Property damage, traffic aids"
# 4      CINCINNATI         SR14009517   CLOS               "Graffiti, removal"
#
#   service_code  \
# 0    "MTL-FRN"
# 1      "STSGN"
# 2     "SLPYST"
# 3   "PRDMTAID"
# 4     "GRFITI"
#
#                                                                                            description  \
# 0                                "THere will also be a vacuum cleaner, and carpet cleaner for pick up"
# 1                                                                   "southwest corner of intersection"
# 2                "Request entered through the Web. Refer to Intake Questions for further description."
# 3  "Transfer: 02/06/2014 6:43 AM/DCOTTRELLPlease check, mailbox was distroyed by snow plow - Reques...
# 4                "Request entered through the Web. Refer to Intake Questions for further description."
#
#   agency_responsible    requested_datetime      updated_datetime  \
# 0    Public Services  2014-02-05T23:21:00Z  2014-02-28T00:00:00Z
# 1    Public Services  2014-02-05T23:21:00Z  2014-02-13T00:00:00Z
# 2    Public Services  2014-02-05T23:23:00Z  2014-03-07T00:00:00Z
# 3    Public Services  2014-02-05T23:24:00Z  2014-03-27T00:00:00Z
# 4    Public Services  2014-02-05T23:28:00Z  2014-02-13T00:00:00Z
#
#       expected_datetime                                      address  zipcode  \
# 0  2014-02-19T00:00:00Z      "4601 CRAWFORD AV, CINC - GJ1298238864"    45223
# 1  2014-02-06T00:00:00Z                      "MAIN ST & WOODWARD ST"    45202
# 2  2014-02-06T00:00:00Z  "2779 MORNINGRIDGE DR, CINC - GJ0839534632"    45211
# 3  2014-02-20T00:00:00Z      "4601 CRAWFORD AV, CINC - GJ1298238864"    45223
# 4  2014-03-07T00:00:00Z          "1227 MAIN ST, CINC - GJ1512631874"    45202
#
#     latitude  longitude           requested_date             updated_date  \
# 0  39.172947 -84.534519  2014-02-05T00:00:00.000  2014-02-28T00:00:00.000
# 1  39.110518 -84.511968  2014-02-05T00:00:00.000  2014-02-13T00:00:00.000
# 2  39.135951 -84.588884  2014-02-05T00:00:00.000  2014-03-07T00:00:00.000
# 3  39.172947 -84.534519  2014-02-05T00:00:00.000  2014-03-27T00:00:00.000
# 4  39.109491 -84.511949  2014-02-05T00:00:00.000  2014-02-13T00:00:00.000
#
#          last_table_update
# 0  2015-03-05T23:07:49.000
# 1  2015-03-05T23:07:49.000
# 2  2015-03-05T23:07:49.000
# 3  2015-03-05T23:07:49.000
# 4  2015-03-05T23:07:49.000

# %% [markdown]
# Aggregate total counts of requests by `agency_responsible` for the past year.

# %%
total_agency_responsible_query = (
    
    generate_query(endpoint_url = endpoint_311, 
                   query = f"""select agency_responsible, 
                                      count(*) as n
                               where requested_datetime>='{year_ago_today}' 
                               and requested_datetime<='{today}'
                               group by agency_responsible""", 
                   limit = 100000000)
)

# %% [markdown]
# Grouping by `agency_responsible` we see that the bulk of our records lie in 'Public Services' and a few other departments.  In lieu of this information, let's only investigate the Public Services records and break it down by these mysterious `service_code` values.

# %%
agency_responsible_count = pd.read_json(total_agency_responsible_query)

agency_responsible_count \
    .assign(total_requests=lambda x: np.sum(x['n']),
            pct_total=lambda x: x['n'] / x['total_requests']) \
    .sort_values(by='pct_total', ascending = False).head(10)
# Out:
#        agency_responsible      n  total_requests  pct_total
# 13        Public Services  69303           95332   0.726965
# 4      Cinc Building Dept   5585           95332   0.058585
# 1   City Manager's Office   5271           95332   0.055291
# 2       Police Department   4611           95332   0.048368
# 6        Cinc Health Dept   4560           95332   0.047833
# 15  Dept of Trans and Eng   3514           95332   0.036861
# 16        Park Department    748           95332   0.007846
# 8         Cin Water Works    493           95332   0.005171
# 9               Fire Dept    413           95332   0.004332
# 3      Metropolitan Sewer    343           95332   0.003598

# %% [markdown]
# #### Filter to Public Services only and aggregate the counts across the entire city

# %%
total_services_query = (
    
generate_query(endpoint_url = endpoint_311, 
               query = f"""select service_code, 
                                  service_name, 
                                  count(*) as n 
                           where requested_datetime>='{year_ago_today}' 
                           and requested_datetime<='{today}' 
                           and agency_responsible == 'Public Services'
                           group by service_code, 
                                    service_name""", 
               limit = 10000000)

)

# %%
total_services = pd.read_json(total_services_query) \
    .assign(total_n=lambda x: np.sum(x['n']),
            pct_total=lambda x: x['n'] / x['total_n']) \
    .sort_values(by = 'pct_total', ascending = False)

total_services.head(10)
# Out:
#    service_code                      service_name      n  total_n  pct_total
# 46    "MTL-FRN"  "Metal Furniture, Spec Collectn"  24921    69303   0.359595
# 77   "RF-COLLT"   "Trash, request for collection"   5244    69303   0.075668
# 85   "YDWSTA-J"                  "Yard waste,rtc"   3435    69303   0.049565
# 70   "LITR-PRV"        "Litter, private property"   3394    69303   0.048973
# 36     "PTHOLE"                 "Pothole, repair"   3074    69303   0.044356
# 99   "TLGR-PRV"  "Tall grass/weeds, private prop"   2970    69303   0.042855
# 79     "SLPYST"       "Slippery streets, request"   2709    69303   0.039089
# 63   "TGGDCLLC"       "Trash, tagged collections"   2268    69303   0.032726
# 45   "TRSHCRTR"        "Trash cart, registration"   2161    69303   0.031182
# 67     "STRSGN"             "Sign, down/missing "   1469    69303   0.021197

# %%
zipcode_services_query = (
    
generate_query(endpoint_url = endpoint_311, 
               query = f"""select zipcode,
                                  service_code, 
                                  service_name, 
                                  count(*) as n
                           where requested_datetime>='{year_ago_today}' 
                           and requested_datetime<='{today}' 
                           and agency_responsible == 'Public Services'
                           group by zipcode,
                                    service_code, 
                                    service_name""", 
               limit = 100000000)

)

# %%
zipcode_services = pd.read_json(zipcode_services_query) \
    .groupby('zipcode') \
    .apply(lambda x: x.assign(total_n=np.sum(x['n']))) \
    .assign(pct_total=lambda x: x['n'] / x['total_n'])


zipcode_services \
    .sort_values(by='pct_total', ascending = False).head(10)
# Out:
#               zipcode service_code                      service_name     n  \
# zipcode
# 45002.0 1606  45002.0     "SLPYST"       "Slippery streets, request"     1
# 45249.0 1512  45249.0     "SLPYST"       "Slippery streets, request"     1
# 45248.0 1119  45248.0   "MDDVSWNO"  "Media advis, winter operations"     1
# 45244.0 713   45244.0     "PTHOLE"                 "Pothole, repair"     1
# 45230.0 700   45230.0    "MTL-FRN"  "Metal Furniture, Spec Collectn"  1173
# 45251.0 658   45251.0     "DMGNOD"              "Damage Claim - NOD"     1
# 45247.0 894   45247.0     "DMGNOD"              "Damage Claim - NOD"     1
#         864   45247.0   "SVCCMPLT"        "Service complaint, trash"     1
# 45236.0 241   45236.0   "RF-COLLT"   "Trash, request for collection"     3
# 45251.0 1798  45251.0   "SVCCMPLT"        "Service complaint, trash"     1
#
#               total_n  pct_total
# zipcode
# 45002.0 1606        1   1.000000
# 45249.0 1512        1   1.000000
# 45248.0 1119        1   1.000000
# 45244.0 713         1   1.000000
# 45230.0 700      2314   0.506914
# 45251.0 658         2   0.500000
# 45247.0 894         2   0.500000
#         864         2   0.500000
# 45236.0 241         6   0.500000
# 45251.0 1798        2   0.500000

# %%
zipcode_services.merge(total_services, on=['service_code','service_name'], how='left') \
    .assign(service_index=lambda x: x['pct_total_x'] / x['pct_total_y']) \
    .query("n_x > 20") \
    .sort_values(by='service_index', ascending=False) \
    .query("zipcode == 45202") \
    .head(20)
# Out:
#     zipcode service_code                      service_name  n_x  total_n_x  \
# 13  45202.0   "COVID_19"                 "General Inquiry"   27       2591
# 63  45202.0     "GRFITI"               "Graffiti, removal"  100       2591
# 15  45202.0   "CRNRCNOF"         "Corner can, overflowing"   43       2591
# 78  45202.0     "SCLEN1"                 "Street cleaning"  165       2591
# 61  45202.0   "TRSHRQNS"  "Trash, request for new service"   23       2591
# 27  45202.0    "TLGR-PS"   "Tall grass/weeds, PS property"   40       2591
# 2   45202.0   "DUMP-PVS"   "Dumping, prv prop <2500 sq ft"   73       2591
# 45  45202.0     "STRSGN"             "Sign, down/missing "   90       2591
# 39  45202.0   "LITR-PRV"        "Litter, private property"  204       2591
# 11  45202.0   "RWFRNTRT"     "ROW furniture/trash dumping"   37       2591
# 12  45202.0     "PTHOLE"                 "Pothole, repair"  179       2591
# 59  45202.0   "DFLTCITY"                   "Default, City"   51       2591
# 23  45202.0   "YDWSTA-J"                  "Yard waste,rtc"  170       2591
# 53  45202.0    "TRASH-I"         "Trash, improper set out"   65       2591
# 26  45202.0     "SLPYST"       "Slippery streets, request"  119       2591
# 22  45202.0   "RF-COLLT"   "Trash, request for collection"  227       2591
# 35  45202.0     "DAPUB1"                     "Dead animal"   37       2591
# 30  45202.0   "SVCCMPLT"        "Service complaint, trash"   22       2591
# 29  45202.0   "TRSHCRTR"        "Trash cart, registration"   51       2591
# 60  45202.0   "TLGR-PRV"  "Tall grass/weeds, private prop"   68       2591
#
#     pct_total_x   n_y  total_n_y  pct_total_y  service_index
# 13     0.010421    29      69303     0.000418      24.902927
# 63     0.038595   476      69303     0.006868       5.619241
# 15     0.016596   326      69303     0.004704       3.528056
# 78     0.063682  1419      69303     0.020475       3.110185
# 61     0.008877   211      69303     0.003045       2.915614
# 27     0.015438   478      69303     0.006897       2.238292
# 2      0.028174   983      69303     0.014184       1.986342
# 45     0.034736  1469      69303     0.021197       1.638722
# 39     0.078734  3394      69303     0.048973       1.607692
# 11     0.014280   616      69303     0.008889       1.606592
# 12     0.069085  3074      69303     0.044356       1.557521
# 59     0.019684   906      69303     0.013073       1.505659
# 23     0.065612  3435      69303     0.049565       1.323753
# 53     0.025087  1332      69303     0.019220       1.305250
# 26     0.045928  2709      69303     0.039089       1.174959
# 22     0.087611  5244      69303     0.075668       1.157838
# 35     0.014280  1045      69303     0.015079       0.947044
# 30     0.008491   756      69303     0.010909       0.778369
# 29     0.019684  2161      69303     0.031182       0.631248
# 60     0.026245  2970      69303     0.042855       0.612403

# %%
raw_descriptions_query = (
    
generate_query(endpoint_url = endpoint_311, 
               query = f"""select zipcode,
                                  requested_datetime,
                                  service_code,
                                  service_name,
                                  description
                            where requested_datetime>='{year_ago_today}' 
                            and requested_datetime<='{today}' 
                            and agency_responsible == 'Public Services'""",
               limit = 100000000000)

)

# %%
# get rid of 
# get rid of quotation marks in the string
# filter out blank description records
raw_311 = pd.read_json(raw_descriptions_query) \
    .assign(description_clean = lambda x: x['description'].str.replace('[^a-zA-Z\s]', '')
                                                          .str.replace('"', '')
                                                          .str.replace('  ', ' ')
                                                          .str.lower(),
            service_code = lambda x: x['service_code'].str.replace('"', ''),
            service_name = lambda x: x['service_name'].str.replace('"', '')) \
    .query("description_clean != 'request entered through the web refer to intake questions for further description'") \
    .query("description_clean != ' '")
# Out:
# /Users/joebahr/opt/miniconda3/envs/data-science-with-r/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """

# %%
raw_311.head(5)
# Out:
#     zipcode    requested_datetime service_code                   service_name  \
# 7   45238.0  2020-11-10T07:25:00Z     RF-COLLT  Trash, request for collection
# 11  45207.0  2020-11-10T07:49:00Z     TGGDCLLC      Trash, tagged collections
# 12  45227.0  2020-11-10T07:55:00Z     BLKYTMST       Special collections, rtc
# 14  45225.0  2020-11-10T07:58:00Z     CRNRCNOF        Corner can, overflowing
# 15  45207.0  2020-11-10T08:00:00Z     YDWSTA-J                 Yard waste,rtc
#
#                                                                                             description  \
# 7                                                                                          "TRASH RTC "
# 11                                        "TAGGED @ 0748am TOOK TOTER & (3) BAGS/ITEMS - LEFT THE REST"
# 12                                            "- REFRIGERATOR/FREEZER - TWIN BED MATTRESS - BOX SPRING"
# 14  "CORNER CAN OVERFLOWING \nHOUSEHOLD TRASH IS BEING PUT IN THE CAN CITIZEN WOULD LIKE TO SEE IF I...
# 15  "Transfer: 11/10/2020 10:53 AM/DJOHNSON1\nI got 4-5 of leaves bags that need to get pick up. \n ...
#
#                                                                                       description_clean
# 7                                                                                            trash rtc
# 11                                                        tagged am took toter  bagsitems left the rest
# 12                                                     refrigeratorfreezer twin bed mattress box spring
# 14  corner can overflowing \nhousehold trash is being put in the can citizen would like to see if it...
# 15  transfer  amdjohnson\ni got of leaves bags that need to get pick up \n request entered through t...

# %%
# concatenate all strings within the same zipcode
zipcode_descriptions = raw_311.groupby(['zipcode'])['description_clean'].apply(' '.join).reset_index()
zipcode_descriptions.head(5)
# Out:
#    zipcode  \
# 0  45002.0
# 1  45202.0
# 2  45203.0
# 3  45204.0
# 4  45205.0
#
#                                                                                      description_clean
# 0                                        citizen request the street be salted and treated immediately
# 1  transfer  amccolemanentire block was missed yard waste has been out for over a week request ente...
# 2  bolts and debris in the road way  tagged am took toter  bagsitems left the rest tagged am took t...
# 3   tires and trash bags rtc trash cart \nentire street  pu at neff ave  pu at neff\n amsgoodwin ou...
# 4  special collections  yard waste rtc  cans are being left out to block parking spots and the side...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(input = 'content', stop_words='english', smooth_idf = True)

tfidf_vector = tfidf_vectorizer.fit_transform(zipcode_descriptions['description_clean'])

# %%
tfidf_df = pd.DataFrame(tfidf_vector.toarray(), 
                        index=zipcode_descriptions['zipcode'], 
                        columns=tfidf_vectorizer.get_feature_names()).reset_index()

tfidf_df
# Out:
#     zipcode        aa     aaron       aas        ab  abandoned  abanoned  \
# 0   45002.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 1   45202.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2   45203.0  0.000000  0.028588  0.000000  0.000000   0.000000  0.000000
# 3   45204.0  0.000000  0.000000  0.000000  0.000000   0.003075  0.000000
# 4   45205.0  0.000000  0.000000  0.000000  0.002360   0.002519  0.000000
# 5   45206.0  0.000000  0.000000  0.000000  0.000000   0.002424  0.000000
# 6   45207.0  0.000000  0.000000  0.000000  0.000000   0.003393  0.000000
# 7   45208.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 8   45209.0  0.007848  0.000000  0.000000  0.000000   0.000000  0.000000
# 9   45211.0  0.000000  0.000000  0.000000  0.000000   0.002938  0.000000
# 10  45212.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 11  45213.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 12  45214.0  0.000000  0.000000  0.000000  0.000000   0.002505  0.000000
# 13  45215.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 14  45216.0  0.000000  0.000000  0.000000  0.000000   0.004173  0.000000
# 15  45217.0  0.000000  0.000000  0.000000  0.000000   0.010594  0.000000
# 16  45219.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 17  45220.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 18  45221.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 19  45223.0  0.000000  0.000000  0.000000  0.000000   0.004511  0.004703
# 20  45224.0  0.000000  0.000000  0.004781  0.000000   0.000000  0.000000
# 21  45225.0  0.000000  0.000000  0.000000  0.000000   0.008194  0.000000
# 22  45226.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 23  45227.0  0.005418  0.000000  0.000000  0.000000   0.005783  0.000000
# 24  45228.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 25  45229.0  0.000000  0.000000  0.000000  0.000000   0.002120  0.000000
# 26  45230.0  0.000000  0.000000  0.000000  0.000000   0.004203  0.000000
# 27  45231.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 28  45232.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 29  45233.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 30  45236.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 31  45237.0  0.000000  0.003587  0.000000  0.003587   0.007658  0.000000
# 32  45238.0  0.000000  0.000000  0.000000  0.000000   0.002236  0.000000
# 33  45239.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 34  45244.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 35  45247.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 36  45248.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 37  45249.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 38  45251.0  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
#
#     abatement     abgle   abigail  ...        yw      zier    zinsle     zip  \
# 0    0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 1    0.000000  0.000000  0.009486  ...  0.026812  0.000000  0.000000  0.0000
# 2    0.000000  0.000000  0.000000  ...  0.019985  0.000000  0.000000  0.0000
# 3    0.000000  0.000000  0.000000  ...  0.026174  0.000000  0.000000  0.0000
# 4    0.000000  0.002360  0.000000  ...  0.030521  0.000000  0.000000  0.0000
# 5    0.000000  0.000000  0.000000  ...  0.042862  0.000000  0.000000  0.0000
# 6    0.000000  0.000000  0.000000  ...  0.019994  0.000000  0.000000  0.0000
# 7    0.000000  0.000000  0.000000  ...  0.076858  0.000000  0.000000  0.0000
# 8    0.000000  0.000000  0.000000  ...  0.043888  0.000000  0.000000  0.0000
# 9    0.000000  0.000000  0.000000  ...  0.045207  0.000000  0.000000  0.0000
# 10   0.000000  0.000000  0.000000  ...  0.048018  0.000000  0.000000  0.0000
# 11   0.000000  0.000000  0.000000  ...  0.060032  0.000000  0.022938  0.0000
# 12   0.000000  0.000000  0.000000  ...  0.018041  0.000000  0.000000  0.0000
# 13   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.1087
# 14   0.000000  0.000000  0.000000  ...  0.051918  0.000000  0.000000  0.0000
# 15   0.000000  0.000000  0.000000  ...  0.131817  0.000000  0.000000  0.0000
# 16   0.006671  0.000000  0.000000  ...  0.052376  0.006671  0.000000  0.0000
# 17   0.000000  0.000000  0.000000  ...  0.050658  0.000000  0.000000  0.0000
# 18   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 19   0.000000  0.004226  0.000000  ...  0.041360  0.000000  0.000000  0.0000
# 20   0.000000  0.000000  0.000000  ...  0.039042  0.000000  0.000000  0.0000
# 21   0.000000  0.000000  0.000000  ...  0.034880  0.000000  0.000000  0.0000
# 22   0.000000  0.000000  0.000000  ...  0.057084  0.000000  0.000000  0.0000
# 23   0.000000  0.000000  0.000000  ...  0.043554  0.000000  0.000000  0.0000
# 24   0.000000  0.000000  0.000000  ...  0.032196  0.000000  0.000000  0.0000
# 25   0.000000  0.000000  0.000000  ...  0.022216  0.000000  0.000000  0.0000
# 26   0.000000  0.000000  0.000000  ...  0.079814  0.000000  0.000000  0.0000
# 27   0.000000  0.000000  0.000000  ...  0.236433  0.000000  0.000000  0.0000
# 28   0.000000  0.000000  0.000000  ...  0.014137  0.000000  0.000000  0.0000
# 29   0.000000  0.000000  0.000000  ...  0.047765  0.000000  0.000000  0.0000
# 30   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 31   0.000000  0.000000  0.000000  ...  0.041373  0.000000  0.000000  0.0000
# 32   0.000000  0.000000  0.000000  ...  0.026360  0.000000  0.000000  0.0000
# 33   0.000000  0.000000  0.000000  ...  0.058736  0.000000  0.000000  0.0000
# 34   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 35   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 36   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 37   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
# 38   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.0000
#
#         zips      zone   zoning       zoo      zoom      zula
# 0   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 1   0.000000  0.006195  0.00000  0.000000  0.009486  0.000000
# 2   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 3   0.000000  0.004187  0.00000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.00788  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 6   0.000000  0.004620  0.00000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 9   0.000000  0.002000  0.00000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.00000  0.026884  0.000000  0.000000
# 18  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 20  0.000000  0.003122  0.00000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 22  0.020196  0.000000  0.00000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 26  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 27  0.000000  0.122911  0.00000  0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 29  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 30  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 31  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 32  0.000000  0.000000  0.00000  0.000000  0.000000  0.009326
# 33  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 34  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 35  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 36  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 37  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 38  0.000000  0.140842  0.00000  0.000000  0.000000  0.000000
#
# [39 rows x 7844 columns]

# %%
tfidf_df \
    .melt(id_vars = 'zipcode', value_vars = tfidf_df.columns) \
    .query("variable not in ('trash','rtc')") \
    .sort_values(by = 'value', ascending = False).head(40)
# Out:
#         zipcode     variable     value
# 243085  45249.0         salt  1.000000
# 267492  45236.0       sunset  0.633035
# 135837  45002.0  immediately  0.605926
# 189888  45248.0      parrish  0.601534
# 142542  45248.0         jill  0.601534
# 117888  45236.0      glenway  0.599353
# 139344  45248.0    interview  0.497185
# 243087  45002.0       salted  0.475674
# 37708   45244.0    beechmont  0.449277
# 250219  45244.0        shift  0.373148
# 75378   45236.0    crosswalk  0.369961
# 283292  45247.0        truck  0.368346
# 282087  45002.0      treated  0.349536
# 144714  45228.0      kellogg  0.338925
# 286395  45221.0   university  0.332504
# 264459  45002.0       street  0.323500
# 102834  45236.0        faded  0.321203
# 223660  45244.0       really  0.311661
# 64019   45224.0   collection  0.311253
# 124990  45244.0         hard  0.299824
# 59397   45002.0      citizen  0.299800
# 232284  45002.0      request  0.299800
# 169362  45228.0       missed  0.297332
# 280801  45202.0     transfer  0.297219
# 169345  45208.0       missed  0.289176
# 48690   45221.0       burnet  0.285195
# 264474  45217.0       street  0.284014
# 252658  45219.0         sign  0.280737
# 33847   45244.0          bad  0.278853
# 280808  45209.0     transfer  0.271059
# 298306  45244.0         wide  0.269468
# 170604  45221.0          mlk  0.268310
# 264490  45237.0       street  0.267620
# 64030   45237.0   collection  0.267589
# 257784  45239.0      special  0.263685
# 169355  45220.0       missed  0.257745
# 116612  45203.0         gest  0.257295
# 232285  45202.0      request  0.256988
# 229773  45228.0      renslar  0.256287
# 300172  45232.0       winton  0.256154

# %%
tfidf_df \
    .melt(id_vars = 'zipcode', value_vars = tfidf_df.columns) \
    .query("variable not in ('trash','rtc')") \
    .query("zipcode == 45202") \
    .sort_values(by = 'value', ascending = False).head(40)
# Out:
#         zipcode     variable     value
# 280801  45202.0     transfer  0.297219
# 232285  45202.0      request  0.256988
# 226123  45202.0        refer  0.249098
# 220741  45202.0    questions  0.246267
# 264460  45202.0       street  0.245364
# 295660  45202.0          web  0.243437
# 97735   45202.0      entered  0.243437
# 83461   45202.0  description  0.243437
# 138802  45202.0       intake  0.243437
# 169339  45202.0       missed  0.155903
# 34048   45202.0         bags  0.129215
# 294607  45202.0        waste  0.106992
# 63532   45202.0    collected  0.101630
# 214462  45202.0      pothole  0.095822
# 303889  45202.0         yard  0.092919
# 5188    45202.0        alley  0.091108
# 252643  45202.0         sign  0.090862
# 59398   45202.0      citizen  0.088802
# 232441  45202.0   requesting  0.083414
# 91846   45202.0       dumped  0.074895
# 64000   45202.0   collection  0.071838
# 152023  45202.0         left  0.069689
# 260404  45202.0           st  0.069631
# 273547  45202.0           th  0.066179
# 262666  45202.0     stickers  0.065724
# 252097  45202.0     sidewalk  0.061180
# 155455  45202.0       litter  0.059610
# 71254   45202.0       corner  0.059526
# 65131   45202.0     columbia  0.058460
# 248158  45202.0          set  0.058082
# 59593   45202.0         city  0.055113
# 177997  45202.0          new  0.055025
# 259975  45202.0           sr  0.053496
# 76207   45202.0         curb  0.052267
# 278461  45202.0        toter  0.052267
# 230374  45202.0       repair  0.049155
# 291058  45202.0         vine  0.048838
# 50779   45202.0       caller  0.046176
# 106315  45202.0       filled  0.045854
# 195859  45202.0         pkwy  0.045582

# %%
raw_311.groupby('description').agg('count').sort_values(by = 'zipcode', ascending = False).head(20)
# Out:
#                                                              zipcode  \
# description
# "SPECIAL COLLECTION "                                           1389
# "RTC"                                                            459
# "SPECIAL COLLECTIONS "                                           409
# "POTHOLE"                                                        178
# "REQUESTING SET OF STICKERS (1)"                                 165
# "RTC- ENTIRE STREET MISSED"                                      135
# "MISSED TRASH COLLECTION "                                       133
# "RTC- CANS"                                                      125
# "REQUESTING SALT TRUCK"                                          112
# "Bags"                                                           103
# "special collection "                                             89
# "TALL GRASS & WEEDS"                                              87
# "1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                  81
# "POTHOLE REPAIR"                                                  80
# "REQUESTING 2 SETS OF REGISTRATION STICKERS "                     79
# "POTHOLE REPAIR "                                                 76
# "POTHOLES"                                                        74
# "LSO"                                                             73
# "RTC- TRASH MISSED"                                               65
# "REQUESTING 1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"       63
#
#                                                              requested_datetime  \
# description
# "SPECIAL COLLECTION "                                                      1389
# "RTC"                                                                       459
# "SPECIAL COLLECTIONS "                                                      409
# "POTHOLE"                                                                   178
# "REQUESTING SET OF STICKERS (1)"                                            165
# "RTC- ENTIRE STREET MISSED"                                                 135
# "MISSED TRASH COLLECTION "                                                  133
# "RTC- CANS"                                                                 125
# "REQUESTING SALT TRUCK"                                                     112
# "Bags"                                                                      103
# "special collection "                                                        89
# "TALL GRASS & WEEDS"                                                         87
# "1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                             81
# "POTHOLE REPAIR"                                                             80
# "REQUESTING 2 SETS OF REGISTRATION STICKERS "                                79
# "POTHOLE REPAIR "                                                            76
# "POTHOLES"                                                                   74
# "LSO"                                                                        73
# "RTC- TRASH MISSED"                                                          65
# "REQUESTING 1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                  63
#
#                                                              service_code  \
# description
# "SPECIAL COLLECTION "                                                1389
# "RTC"                                                                 459
# "SPECIAL COLLECTIONS "                                                409
# "POTHOLE"                                                             178
# "REQUESTING SET OF STICKERS (1)"                                      165
# "RTC- ENTIRE STREET MISSED"                                           135
# "MISSED TRASH COLLECTION "                                            133
# "RTC- CANS"                                                           125
# "REQUESTING SALT TRUCK"                                               112
# "Bags"                                                                103
# "special collection "                                                  89
# "TALL GRASS & WEEDS"                                                   87
# "1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                       81
# "POTHOLE REPAIR"                                                       80
# "REQUESTING 2 SETS OF REGISTRATION STICKERS "                          79
# "POTHOLE REPAIR "                                                      76
# "POTHOLES"                                                             74
# "LSO"                                                                  73
# "RTC- TRASH MISSED"                                                    65
# "REQUESTING 1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"            63
#
#                                                              service_name  \
# description
# "SPECIAL COLLECTION "                                                1389
# "RTC"                                                                 459
# "SPECIAL COLLECTIONS "                                                409
# "POTHOLE"                                                             178
# "REQUESTING SET OF STICKERS (1)"                                      165
# "RTC- ENTIRE STREET MISSED"                                           135
# "MISSED TRASH COLLECTION "                                            133
# "RTC- CANS"                                                           125
# "REQUESTING SALT TRUCK"                                               112
# "Bags"                                                                103
# "special collection "                                                  89
# "TALL GRASS & WEEDS"                                                   87
# "1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                       81
# "POTHOLE REPAIR"                                                       80
# "REQUESTING 2 SETS OF REGISTRATION STICKERS "                          79
# "POTHOLE REPAIR "                                                      76
# "POTHOLES"                                                             74
# "LSO"                                                                  73
# "RTC- TRASH MISSED"                                                    65
# "REQUESTING 1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"            63
#
#                                                              description_clean
# description
# "SPECIAL COLLECTION "                                                     1389
# "RTC"                                                                      459
# "SPECIAL COLLECTIONS "                                                     409
# "POTHOLE"                                                                  178
# "REQUESTING SET OF STICKERS (1)"                                           165
# "RTC- ENTIRE STREET MISSED"                                                135
# "MISSED TRASH COLLECTION "                                                 133
# "RTC- CANS"                                                                125
# "REQUESTING SALT TRUCK"                                                    112
# "Bags"                                                                     103
# "special collection "                                                       89
# "TALL GRASS & WEEDS"                                                        87
# "1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                            81
# "POTHOLE REPAIR"                                                            80
# "REQUESTING 2 SETS OF REGISTRATION STICKERS "                               79
# "POTHOLE REPAIR "                                                           76
# "POTHOLES"                                                                  74
# "LSO"                                                                       73
# "RTC- TRASH MISSED"                                                         65
# "REQUESTING 1 SET OF REGISTRATION STICKERS FOR TRASH TOTER"                 63
